# %%
import ecosystem
import matplotlib.pyplot as plt

# %%
ecosystem.run()
no_inv = ecosystem.eco_data

ecosystem.reset_pops()

ecosystem.run(invasive=True)
inv = ecosystem.eco_data

# %%
plt.plot(no_inv['step'], no_inv['cod_pop'])
plt.plot(inv['step'], inv['cod_pop'])
