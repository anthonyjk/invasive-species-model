# %%
import ecosystem
import matplotlib.pyplot as plt

# %%
ecosystem.run()

# %%
eco_data = ecosystem.eco_data

eco_data
# Out:
#       step  krill_pop  krill_growth  penguin_pop  penguin_growth  \
# 0        0  1350000.0       1500000         1000             200
# 1        1  1408559.0       1500000         1071             214
# 2        2  1416212.0       1500000         1110             223
# 3        3  1413435.0       1500000         1097             221
# 4        4  1411853.0       1500000         1100             223
# ...    ...        ...           ...          ...             ...
# 3645  3645  1418129.0       1500000         1096             215
# 3646  3646  1417203.0       1500000         1092             215
# 3647  3647  1417167.0       1500000         1095             216
# 3648  3648  1416254.0       1500000         1090             216
# 3649  3649  1416241.0       1500000         1094             218
#
#       penguin_death  penguin_krill_consumed  cod_pop  cod_growth  cod_death  \
# 0               120                    1666     2250         726        350
# ...

# %%
ecosystem.test
