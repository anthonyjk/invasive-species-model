# %%
import ecosystem
import matplotlib.pyplot as plt

# %%
ecosystem.run()
# Out:
# 0
# 2759
# 10
# 25
# 0.4359958144401814
# 1
# 2444
# 11
# 25
# 0.5308880308880309
# 2
# 2044
# 12
# 25
# 0.6681514476614699
# 3
# 2275
# 12
# 25
# 0.6100040666937779
# 4
# 2479
# 12
# 25
# 0.5658242172764995

# %%
plt.figure(figsize=(12, 6))

fig, ax = plt.subplots()
xa = ax.twinx()
xa.plot(ecosystem.x, ecosystem.k, label="Krill", color='orange')
ax.plot(ecosystem.x, ecosystem.c, label="Arctic Cod", color='blue')
#xa.plot(ecosystem.x, ecosystem.c, label="Cod", color='orange')
plt.xlabel("Day")
plt.ylabel("Population")
ax.legend(['Arctic Cod'], loc='upper right')
xa.legend(['krill'])
plt.show()

# %%
import numpy as np
#sum(np.array(ecosystem.c) < 750)
ecosystem.k[0:50]
# Out:
# [1394680,
#  1394395,
#  1394703,
#  1395677,
#  1396399,
#  1397029,
#  1397577,
#  1398052,
#  1398490,
#  1398846,
#  1399276,
#  1399413,
#  1399769,
#  1399808,
#  1400085,
#  1400195,
#  1400270,
#  1400320,
#  1400358,
#  1400352,
#  1400353,
#  1400314,
#  1400279,
#  1400226,
#  1400150,
#  1400081,
#  1400010,
#  1399927,
#  1399825,
#  1399699,
#  1399602,
#  1399507,
#  1399531,
#  1399289,
#  1399299,
#  1399014,
#  1399031,
#  1398754,
#  1398755,
#  1398622,
#  1398497,
#  1398346,
#  1398229,
#  1398088,
#  1397984,
#  1397875,
#  1397745,
#  1397625,
#  1397505,
#  1397371]
